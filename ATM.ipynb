# %% [markdown]
# <a href="https://colab.research.google.com/github/kulthoomalabi84-beep/STUDENT-PERFORMANCE-ANALYSER/blob/main/ATM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balance = 50000
print("Welcome to Simple Bank")
correct_pin = False

for _ in range (3):
   pin = input("please enter your pin:")

   if pin == "0310":
    correct_pin = True
    break
else:
  print("Incorrect pin")

if correct_pin == True:
  option = ""

  while option != "4":
    print("MENU")
    print ("1.Check balance")
    print("2. Deposit money")
    print("3. Withdraw money")
    print("4. Exit")

    option= input("choose an option:")

if option == "1":
    print(balance)
elif option == "2":
 amount = int(input("Amount to deposit: "))
 balance = balance + amount
 print("deposit sucessful")
elif option == "3":
 amount = int(input("Amount to withdraw:"))

 if amount <= balance:
   balance = balance - amount
   print("Withdrawal sucessful")
 else:
   print("Insufficient balance")

elif option == "4":
  print("Thank you for choosing Simple Bank")
  break
# Out:
# Welcome to Simple Bank
# please enter your pin:gyug
# please enter your pin:iughiu
# please enter your pin:lkmnkl
# Incorrect pin
#   File "/tmp/ipykernel_1940/1354068765.py", line 43
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
print("$" * 51)
print("$"*14 + " WELCOME TO SIMPLE BANK " + "$" * 14)
print("Please insert your card")

balance = 50000
correct_pin ="0000"
logged_in = False



for attempt in range(3):
  pin = input("Enter your valid PIN")
  if pin == correct_pin:
    print("logged successful")
    logged_in = True
    break


  else:
    print("incorrect pin")

if logged_in:
  while True:
    print("***MENU***")
    print("1.Check balance")
    print("2.Withdraw money")
    print("3.Deposit money")
    print("4.Exit")
    option = input("Choose an option: ")
    if option == "1":
      print(balance)

    elif option == "2":
      amount=int(input("Enter amount you want to withdraw"))
      if amount <= balance:
        balance = balance - amount
        print(str(amount) + "Withdrawn sucessfully")
      else:
        print("Insufficient balance")

    elif option =="3":
      amount2=int(input("Enter the amount you want to deposit"))
      balance = balance + amount2
      print(str(amount2)+ "......Deposited sucessfully")
      print("Your new balance is....." + str(balance))

    elif option == "4":
      print("Thank you for using our bank")
      break

    else:
      print("INVALID OPTION... PLEASE CHOOSE 1,2,3 OR 4")

else:
  print("...YOU HAVE ENTERED WRONG PIN 3 TIMES...")
  print("..YOUR ACCOUNT IS LOCKED..")
# Out:
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$ WELCOME TO SIMPLE BANK $$$$$$$$$$$$$$
# Please insert your card
# logged successful
# ***MENU***
# 1.Check balance
# 2.Withdraw money
# 3.Deposit money
# 4.Exit
# 50000
# ***MENU***
# 1.Check balance
# 2.Withdraw money
# 3.Deposit money
# 4.Exit
# 50000
# ***MENU***
# 1.Check balance
# 2.Withdraw money
# 3.Deposit money
# 4.Exit
# 2000Withdrawn sucessfully
# ***MENU***
# 1.Check balance
# 2.Withdraw money
# 3.Deposit money
# 4.Exit
