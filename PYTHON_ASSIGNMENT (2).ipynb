# %% [markdown]
# # New Section

# %%
name="Abdul"
age=21
department="computer science"
mathematics=75
python=82
statistics=68
Totalscore=mathematics+python+statistics
Averagescore=Totalscore/3
Lowestscore=min(mathematics,python,statistics)
Highestscore=max(mathematics,python,statistics)
Passed=Averagescore>=50

print(name)
print(age)
print(department)
print(mathematics)
print(python)
print(statistics)
print(Totalscore)
print(Averagescore)
print(Lowestscore)
print(Highestscore)
print(Passed)
# Out:
# Abdul
# 21
# computer science
# 75
# 82
# 68
# 225
# 75.0
# 68
# 82
# True

# %%
name=abdul
